# %%
import sys
import os
import numpy as np
#import serial
# ser = serial.Serial('/dev/ttyUSB0', 9600, timeout=1)
statinfo = os.stat('./minicom.log')
f = open('./minicom.log', 'rb')
msg = ["" for x in range(1000)]
msg_index = 0

WAD_wind = np.zeros((1,3))

for b in range(statinfo.st_size):
    f.seek(b)
    byte = f.read(1)
    if ord(byte) == 0x1E:
        msg = f.read(9)

        if msg[0] == 'A':                    # Analog input 
            a = msg[1:7]
            if a == '    --':
                a = float('NaN')
            else:
                a = int(a)/10.0
            sys.stdout.write(" Temperature: %3.1f C\n" % (a))
        elif msg[0] == 'B':                    # Analog input 
            b = int(msg[1:7])/10.0
            sys.stdout.write(" Pressure: %3.1f hPa \n" % (b))
        elif msg[0] == 'C':                    # Analog input 
            c = int(msg[1:7])/10.0
            sys.stdout.write(" QFE: %4.1f hPa\n" % (c))
        elif msg[0] == 'D':                    # Analog input 
            d = int(msg[1:7])/10.0
            sys.stdout.write(" QNH: %4.1f hPa\n" % (d))
            
        elif msg[0] == 'E':                    # precipitation input
            precipitation = int(msg[1:7])
            
        elif msg[0] == 'G':                    # wind speed and direction
            wind_direction =  int(msg[1:3]) * 10
            wind_speed =  int(msg[3:7])/10.0
            wind = (wind_speed), (wind_direction)
            sys.stdout.write(" Windspeed: %3.1f kt Winddirection: %d \n" % (wind_speed,wind_direction))
            
        elif msg[0] == 'H':                    # wind speed and direction (2 minutes sliding average)
            wind_direction =  int(msg[1:3]) * 10
            wind_speed =  int(msg[3:7])/10.0
            wind_2min = (wind_speed), (wind_direction)
            sys.stdout.write(" Windspeed: %3.1f kt Winddirection: %d  2 minutes average \n" % (wind_speed,wind_direction))

        elif msg[0] == 'I':                    # wind speed and direction (10 minutes sliding average)
            wind_direction =  int(msg[1:3])* 10
            wind_speed =  int(msg[3:7])/10.0
            wind_10min = (wind_speed), (wind_direction )
            sys.stdout.write(" Windspeed: %3.1f kt Direction: %d knots 10 minutes average.\n" % (wind_speed,wind_direction))

        elif msg[0] == 'L':                    # Dewpoint temperature
            dewpoint = msg[1:7]
            if dewpoint == '    --':
                dewpoint = float('NaN')
            else:
                dewpoint = int(dewpoint)/10.0
            sys.stdout.write(" Dewpoint: %3.1f \n" % (dewpoint))

        elif msg[0] == 'M':                    # 3hours pressure trend
            pressure_3h = int(msg[1:7])/10.0
            sys.stdout.write(" Pressure %4.1f hPa 3 hours trend.\n" % (pressure_3h))

        elif msg[0] == 'Q':                    # power status in % (0-100% is internal power capacity) if external power supply present value is greater than 100
            power = int(msg[1:7])
            sys.stdout.write(" Power %d \% \n" % (power))

        elif msg[0] == 'R':                    # alarm or relay status
            alarm = int(msg[1:7])
            sys.stdout.write(" Alarm status %d \n" % (alarm))

        elif msg[0] == 'S':                    # atmospheric stability
            atmosphere_stability = int(msg[1:7])
            sys.stdout.write(" Atmospheric stability  %d \n" % (atmosphere_stability))

        elif msg[0] == 'W':                    # WAD software special format
            wind_direction = 10*(16*(ord(msg[1]) & 0x0F) + (ord(msg[2]) & 0x0F))
            wind_speed =  256*(16*(ord(msg[3]) & 0x0F) + (ord(msg[4]) & 0x0F)) + 16*(ord(msg[5]) & 0x0F) + (ord(msg[6]) & 0x0F)
            wind_speed_ms = wind_speed / 37.38932004
            wind_speed_kt = wind_speed_ms * 1.943844492
            WAD_wind = np.append(WAD_wind,[[wind_speed_ms, wind_speed_kt, wind_direction]], axis=0)
            sys.stdout.write(" WAD Winddirection %d %3.1f m/s %3.1f kt \n" % (wind_direction, wind_speed_ms, wind_speed_kt))

        elif msg[0] == 'X':                    # WAD software special format 2 minutes average
            wind_WAD_2min = msg[1:7]
            sys.stdout.write(" WAD %s 2min\n" % (wind_WAD_2min))

        elif msg[0] == 'Y':                    # WAD software special format 10 minutes average
            wind_WAD_10min = msg[1:7]
            sys.stdout.write(" WAD %s 10min\n" % (wind_WAD_10min))
        
f.close()
# Out:
#  WAD Winddirection 0 0.8 m/s 1.6 kt
#  Windspeed: 1.5 kt Winddirection: 0
#  Dewpoint: nan
#  Pressure: 1212.0 hPa
#  WAD Winddirection 0 0.7 m/s 1.3 kt
#  Windspeed: 1.3 kt Winddirection: 0
#  QFE: 968.7 hPa
#  WAD Winddirection 0 0.7 m/s 1.4 kt
#  Windspeed: 1.3 kt Winddirection: 0
#  QNH: 1016.6 hPa
#  WAD Winddirection 0 0.7 m/s 1.3 kt
#  Windspeed: 1.3 kt Winddirection: 0
#  Temperature: 6.5 C
#  WAD Winddirection 110 0.6 m/s 1.2 kt
#  Windspeed: 1.2 kt Winddirection: 110
#  Dewpoint: nan
#  Pressure: 1212.0 hPa
#  WAD Winddirection 110 0.7 m/s 1.3 kt
#  Windspeed: 1.3 kt Winddirection: 110
#  QFE: 968.6 hPa
#  WAD Winddirection 110 0.6 m/s 1.2 kt
#  Windspeed: 1.2 kt Winddirection: 110
#  QNH: 1016.6 hPa
#  WAD Winddirection 0 0.6 m/s 1.2 kt
#  Windspeed: 1.2 kt Winddirection: 0
#  Temperature: 6.5 C
#  WAD Winddirection 110 0.6 m/s 1.1 kt
#  Windspeed: 1.1 kt Winddirection: 110
#  WAD p\ppaZ 2min
#  Windspeed: 1.3 kt Winddirection: 120  2 minutes average
#  WAD p\ppa\ 10min
#  Windspeed: 1.4 kt Direction: 120 knots 10 minutes average.
#  Dewpoint: nan
#  Pressure: 1212.0 hPa
#  WAD Winddirection 0 0.7 m/s 1.3 kt
#  Windspeed: 1.3 kt Winddirection: 0
#  QFE: 968.7 hPa
#  WAD Winddirection 0 0.7 m/s 1.4 kt
#  Windspeed: 1.3 kt Winddirection: 0
#  QNH: 1016.6 hPa
#  WAD Winddirection 110 0.5 m/s 1.0 kt
#  Windspeed: 1.0 kt Winddirection: 110
#  Temperature: 6.6 C
#  WAD Winddirection 110 0.6 m/s 1.2 kt
#  Windspeed: 1.2 kt Winddirection: 110
#  Dewpoint: nan
#  Pressure: 1212.0 hPa
#  WAD Winddirection 0 0.7 m/s 1.4 kt
#  Windspeed: 1.3 kt Winddirection: 0
#  QFE: 968.6 hPa
#  WAD Winddirection 0 0.7 m/s 1.4 kt
#  Windspeed: 1.3 kt Winddirection: 0
#  QNH: 1016.6 hPa
#  WAD Winddirection 110 0.5 m/s 1.0 kt
#  Windspeed: 1.0 kt Winddirection: 110
#  Temperature: 6.6 C
#  WAD Winddirection 0 0.6 m/s 1.2 kt
#  Windspeed: 1.2 kt Winddirection: 0
#  Dewpoint: nan
#  Pressure: 1212.0 hPa
#  WAD Winddirection 0 0.6 m/s 1.2 kt
#  Windspeed: 1.2 kt Winddirection: 0
#  WAD p\ppaY 2min
#  Windspeed: 1.3 kt Winddirection: 120  2 minutes average
#  WAD p\ppa\ 10min
#  Windspeed: 1.4 kt Direction: 120 knots 10 minutes average.
#  QFE: 968.7 hPa
#  WAD Winddirection 0 0.7 m/s 1.3 kt
#  Windspeed: 1.3 kt Winddirection: 0
#  QNH: 1016.6 hPa
#  WAD Winddirection 110 0.7 m/s 1.3 kt
#  Windspeed: 1.3 kt Winddirection: 110
#  Temperature: 6.6 C
#  WAD Winddirection 0 0.7 m/s 1.4 kt
#  Windspeed: 1.4 kt Winddirection: 0
#  Dewpoint: nan
#  Pressure: 1212.0 hPa
#  WAD Winddirection 0 0.6 m/s 1.1 kt
#  Windspeed: 1.1 kt Winddirection: 0
#  QFE: 968.7 hPa
#  WAD Winddirection 0 0.6 m/s 1.2 kt
#  Windspeed: 1.2 kt Winddirection: 0
#  QNH: 1016.6 hPa
#  WAD Winddirection 0 0.7 m/s 1.4 kt
#  Windspeed: 1.3 kt Winddirection: 0
#  Temperature: 6.6 C
#  WAD Winddirection 0 0.7 m/s 1.4 kt
#  Windspeed: 1.4 kt Winddirection: 0
#  Dewpoint: nan
#  Pressure: 1212.0 hPa
#  WAD Winddirection 110 0.7 m/s 1.4 kt
#  Windspeed: 1.4 kt Winddirection: 110
#  WAD p\ppaY 2min
#  Windspeed: 1.3 kt Winddirection: 120  2 minutes average
#  WAD p\ppa\ 10min
#  Windspeed: 1.4 kt Direction: 120 knots 10 minutes average.
#  QFE: 968.7 hPa
#  WAD Winddirection 0 0.7 m/s 1.4 kt
#  Windspeed: 1.4 kt Winddirection: 0
#  QNH: 1016.6 hPa
#  WAD Winddirection 0 0.8 m/s 1.6 kt
#  Windspeed: 1.5 kt Winddirection: 0
#  Temperature: 6.6 C
#  WAD Winddirection 110 0.8 m/s 1.6 kt
#  Windspeed: 1.6 kt Winddirection: 110
#  Dewpoint: nan
#  Pressure: 1212.0 hPa
#  WAD Winddirection 0 0.8 m/s 1.6 kt
#  Windspeed: 1.6 kt Winddirection: 0
#  QFE: 968.7 hPa
#  WAD Winddirection 110 0.8 m/s 1.6 kt
#  Windspeed: 1.5 kt Winddirection: 110
#  QNH: 1016.6 hPa
#  WAD Winddirection 0 0.8 m/s 1.6 kt
#  Windspeed: 1.6 kt Winddirection: 0
#  Temperature: 6.6 C
#  WAD Winddirection 0 0.9 m/s 1.7 kt
#  Windspeed: 1.7 kt Winddirection: 0
#  Dewpoint: nan
#  Pressure: 1212.0 hPa
#  WAD Winddirection 0 0.8 m/s 1.6 kt
#  Windspeed: 1.6 kt Winddirection: 0
#  Pressure  1.3 hPa 3 hours trend.
#  QFE: 968.7 hPa
#  WAD Winddirection 110 0.8 m/s 1.6 kt
#  Windspeed: 1.6 kt Winddirection: 110
#  WAD p\ppaZ 2min
#  Windspeed: 1.3 kt Winddirection: 120  2 minutes average
#  WAD p\ppa\ 10min
#  Windspeed: 1.4 kt Direction: 120 knots 10 minutes average.
#  QNH: 1016.6 hPa
#  WAD Winddirection 0 0.9 m/s 1.7 kt
#  Windspeed: 1.7 kt Winddirection: 0
#  Temperature: 6.6 C
#  WAD Winddirection 110 0.9 m/s 1.8 kt
#  Windspeed: 1.7 kt Winddirection: 110
#  Dewpoint: nan
#  Pressure: 1212.0 hPa
#  WAD Winddirection 0 0.8 m/s 1.6 kt
#  Windspeed: 1.6 kt Winddirection: 0
#  QFE: 968.7 hPa
#  WAD Winddirection 110 0.8 m/s 1.6 kt
#  Windspeed: 1.5 kt Winddirection: 110
#  QNH: 1016.6 hPa
#  WAD Winddirection 120 0.8 m/s 1.6 kt
#  Windspeed: 1.6 kt Winddirection: 120
#  Temperature: 6.6 C
#  WAD Winddirection 0 0.8 m/s 1.5 kt
#  Windspeed: 1.5 kt Winddirection: 0
#  Dewpoint: nan
#  Pressure: 1212.0 hPa
#  WAD Winddirection 110 0.8 m/s 1.5 kt
#  Windspeed: 1.5 kt Winddirection: 110
#  QFE: 968.7 hPa
#  WAD Winddirection 110 0.8 m/s 1.6 kt
#  Windspeed: 1.5 kt Winddirection: 110
#  WAD pKppaZ 2min
#  Windspeed: 1.3 kt Winddirection: 110  2 minutes average
#  WAD p\ppa\ 10min
#  Windspeed: 1.4 kt Direction: 120 knots 10 minutes average.
#  QNH: 1016.6 hPa
#  WAD Winddirection 0 0.7 m/s 1.4 kt
#  Windspeed: 1.4 kt Winddirection: 0
#  Temperature: 6.6 C
#  WAD Winddirection 0 0.6 m/s 1.1 kt
#  Windspeed: 1.1 kt Winddirection: 0
#  Dewpoint: nan
#  Pressure: 1212.0 hPa
#  WAD Winddirection 0 0.6 m/s 1.1 kt
#  Windspeed: 1.1 kt Winddirection: 0
#  QFE: 968.7 hPa
#  WAD Winddirection 0 0.6 m/s 1.1 kt
#  Windspeed: 1.1 kt Winddirection: 0
#  QNH: 1016.6 hPa
#  WAD Winddirection 0 0.6 m/s 1.2 kt
#  Windspeed: 1.2 kt Winddirection: 0
#  Temperature: 6.6 C
#  WAD Winddirection 0 0.5 m/s 1.0 kt
#  Windspeed: 1.0 kt Winddirection: 0
#  Dewpoint: nan
#  Pressure: 1212.0 hPa
#  WAD Winddirection 0 0.6 m/s 1.2 kt
#  Windspeed: 1.2 kt Winddirection: 0
#  QFE: 968.7 hPa
#  WAD Winddirection 0 0.6 m/s 1.2 kt
#  Windspeed: 1.2 kt Winddirection: 0
#  QNH: 1016.6 hPa
#  WAD Winddirection 110 0.6 m/s 1.2 kt
#  Windspeed: 1.2 kt Winddirection: 110
#  WAD pKppaZ 2min
#  Windspeed: 1.3 kt Winddirection: 110  2 minutes average
#  WAD p\ppa\ 10min
#  Windspeed: 1.4 kt Direction: 120 knots 10 minutes average.
#  Temperature: 6.6 C
#  WAD Winddirection 0 0.6 m/s 1.2 kt
#  Windspeed: 1.2 kt Winddirection: 0
#  Dewpoint: nan
#  Pressure: 1212.0 hPa
#  WAD Winddirection 0 0.6 m/s 1.2 kt
#  Windspeed: 1.2 kt Winddirection: 0
#  QFE: 968.7 hPa
#  WAD Winddirection 0 0.6 m/s 1.2 kt
#  Windspeed: 1.2 kt Winddirection: 0
#  QNH: 1016.6 hPa
#  WAD Winddirection 0 0.6 m/s 1.1 kt
#  Windspeed: 1.1 kt Winddirection: 0
#  Temperature: 6.6 C
#  WAD Winddirection 0 0.6 m/s 1.2 kt
#  Windspeed: 1.2 kt Winddirection: 0
#  Dewpoint: nan
#  Pressure: 1212.0 hPa
#  WAD Winddirection 100 0.5 m/s 1.0 kt
#  Windspeed: 1.0 kt Winddirection: 100
#  QFE: 968.7 hPa
#  WAD Winddirection 100 0.5 m/s 0.9 kt
#  Windspeed: 0.9 kt Winddirection: 100
#  QNH: 1016.6 hPa
#  WAD Winddirection 0 0.5 m/s 0.9 kt
#  Windspeed: 0.9 kt Winddirection: 0
#  WAD pKppaZ 2min
#  Windspeed: 1.3 kt Winddirection: 110  2 minutes average
#  WAD p\ppa\ 10min
#  Windspeed: 1.4 kt Direction: 120 knots 10 minutes average.
#  Temperature: 6.6 C
#  WAD Winddirection 0 0.5 m/s 1.0 kt
#  Windspeed: 1.0 kt Winddirection: 0
#  Dewpoint: nan
#  Pressure: 1212.0 hPa
#  WAD Winddirection 110 0.6 m/s 1.1 kt
#  Windspeed: 1.1 kt Winddirection: 110
#  QFE: 968.7 hPa
#  WAD Winddirection 100 0.7 m/s 1.3 kt
#  Windspeed: 1.3 kt Winddirection: 100
#  QNH: 1016.6 hPa
#  WAD Winddirection 100 0.6 m/s 1.2 kt
#  Windspeed: 1.2 kt Winddirection: 100
#  Temperature: 6.6 C
#  WAD Winddirection 0 0.8 m/s 1.5 kt
#  Windspeed: 1.5 kt Winddirection: 0
#  Dewpoint: nan
#  Pressure: 1212.0 hPa
#  WAD Winddirection 0 0.7 m/s 1.3 kt
#  Windspeed: 1.3 kt Winddirection: 0
#  QFE: 968.7 hPa
#  WAD Winddirection 0 0.7 m/s 1.4 kt
#  Windspeed: 1.3 kt Winddirection: 0
#  QNH: 1016.6 hPa
#  WAD Winddirection 0 0.7 m/s 1.3 kt
#  Windspeed: 1.3 kt Winddirection: 0
#  Temperature: 6.6 C
#  WAD Winddirection 100 0.8 m/s 1.5 kt
#  Windspeed: 1.5 kt Winddirection: 100
#  WAD pKppaZ 2min
#  Windspeed: 1.3 kt Winddirection: 110  2 minutes average
#  WAD p\ppa\ 10min
#  Windspeed: 1.4 kt Direction: 120 knots 10 minutes average.
#  Dewpoint: nan
#  Pressure: 1212.0 hPa
#  WAD Winddirection 0 0.8 m/s 1.5 kt
#  Windspeed: 1.5 kt Winddirection: 0
#  QFE: 968.7 hPa
#  WAD Winddirection 100 0.8 m/s 1.5 kt
#  Windspeed: 1.5 kt Winddirection: 100
#  QNH: 1016.6 hPa
#  WAD Winddirection 100 0.8 m/s 1.6 kt
#  Windspeed: 1.5 kt Winddirection: 100
#  Temperature: 6.6 C
#  WAD Winddirection 0 0.8 m/s 1.6 kt
#  Windspeed: 1.5 kt Winddirection: 0
#  Dewpoint: nan
#  Pressure: 1212.0 hPa
#  WAD Winddirection 100 0.8 m/s 1.5 kt
#  Windspeed: 1.5 kt Winddirection: 100
#  QFE: 968.7 hPa
#  WAD Winddirection 0 0.8 m/s 1.5 kt
#  Windspeed: 1.5 kt Winddirection: 0
#  QNH: 1016.6 hPa
#  WAD Winddirection 0 0.8 m/s 1.5 kt
#  Windspeed: 1.5 kt Winddirection: 0
#  Temperature: 6.6 C
#  WAD Winddirection 0 0.8 m/s 1.6 kt
#  Windspeed: 1.6 kt Winddirection: 0
#  Dewpoint: nan
#  Pressure: 1212.0 hPa
#  WAD Winddirection 0 0.8 m/s 1.6 kt
#  Windspeed: 1.5 kt Winddirection: 0
#  WAD pKppaZ 2min
#  Windspeed: 1.3 kt Winddirection: 110  2 minutes average
#  WAD p\ppa\ 10min
#  Windspeed: 1.4 kt Direction: 120 knots 10 minutes average.
#  QFE: 968.7 hPa
#  WAD Winddirection 0 0.9 m/s 1.7 kt
#  Windspeed: 1.7 kt Winddirection: 0
#  QNH: 1016.6 hPa
#  WAD Winddirection 0 0.7 m/s 1.4 kt
#  Windspeed: 1.4 kt Winddirection: 0
#  Temperature: 6.6 C
#  WAD Winddirection 0 0.7 m/s 1.4 kt
#  Windspeed: 1.4 kt Winddirection: 0
#  Dewpoint: nan
#  Pressure: 1212.0 hPa
#  WAD Winddirection 100 0.7 m/s 1.4 kt
#  Windspeed: 1.3 kt Winddirection: 100
#  QFE: 968.7 hPa
#  WAD Winddirection 0 0.8 m/s 1.6 kt
#  Windspeed: 1.5 kt Winddirection: 0
#  QNH: 1016.6 hPa
#  WAD Winddirection 0 0.8 m/s 1.6 kt
#  Windspeed: 1.5 kt Winddirection: 0
#  Temperature: 6.6 C
#  WAD Winddirection 100 0.7 m/s 1.3 kt
#  Windspeed: 1.3 kt Winddirection: 100
#  Dewpoint: nan
#  Pressure: 1212.0 hPa
#  WAD Winddirection 100 0.8 m/s 1.5 kt
#  Windspeed: 1.5 kt Winddirection: 100
#  WAD pKppaZ 2min
#  Windspeed: 1.3 kt Winddirection: 110  2 minutes average
#  WAD p\ppa\ 10min
#  Windspeed: 1.4 kt Direction: 120 knots 10 minutes average.
#  Pressure  1.4 hPa 3 hours trend.
#  QFE: 968.7 hPa
#  WAD Winddirection 0 0.7 m/s 1.4 kt
#  Windspeed: 1.4 kt Winddirection: 0
#  QNH: 1016.6 hPa
#  WAD Winddirection 0 0.7 m/s 1.3 kt
#  Windspeed: 1.3 kt Winddirection: 0
#  Temperature: 6.6 C
#  WAD Winddirection 100 0.7 m/s 1.4 kt
#  Windspeed: 1.3 kt Winddirection: 100
#  Dewpoint: nan
#  Pressure: 1212.0 hPa
#  WAD Winddirection 0 0.7 m/s 1.4 kt
#  Windspeed: 1.4 kt Winddirection: 0
#  QFE: 968.7 hPa

# %%
import sys
from vispy import scene
from vispy.geometry.torusknot import TorusKnot

from colorsys import hsv_to_rgb
import numpy as np

canvas = scene.SceneCanvas(keys='interactive')
canvas.view = canvas.central_widget.add_view()

#points = np.random.rand(30,2)
points = WAD_wind[:,[0,2]]
points[:,[0, 1]] = points[:,[1, 0]]

#points = np.multiply(points, [360,1])
time = np.split(np.linspace(0.0, 10.0, num=points.shape[0]),points.shape[0])
points = np.hstack((points,time))

center_points = np.zeros((points.shape[0],2))
center_points = np.hstack((center_points,time))
lines = np.empty((points.shape[0]+center_points.shape[0],points.shape[1]))
lines[::2,:] = points
lines[1::2,:] = center_points
lines[1::2,:] = center_points


colors = np.linspace(0, 1, len(points))
colors = np.array([hsv_to_rgb(c, 1, 1) for c in colors])

l2 = scene.visuals.Tube(([0,0,0],[0,0,1]),
                        color=['red', 'green', 'blue'],
                        shading='smooth',
                        tube_points=8)

l1 = scene.visuals.Line(pos=lines,
                        connect='segments',
                        color='white',
                        mode='gl',
                        width=5,
                        antialias=True)
l1.transform = scene.transforms.PolarTransform()

grid = scene.visuals.GridLines()
grid.transform = scene.transforms.PolarTransform()

axes = scene.visuals.XYZAxis()
axes.transform = scene.transforms.PolarTransform()

title = scene.visuals.Text(text = 'Wind parameters', color = 'red',pos = (0,1), font_size = 12,)

canvas.view.add(l1)
canvas.view.add(axes)
canvas.view.add(title)
#canvas.view.add(grid)

canvas.view.set_camera('turntable', mode='perspective',
                       up='z', distance=10)

# %%
canvas.show()
canvas.app.run()
# Out:
# 0

# %%
points
# Out:
# array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   8.02368162e-01,   1.11111111e-01],
#        [  0.00000000e+00,   6.68640135e-01,   2.22222222e-01],
#        [  0.00000000e+00,   6.95385740e-01,   3.33333333e-01],
#        [  0.00000000e+00,   6.68640135e-01,   4.44444444e-01],
#        [  1.10000000e+02,   6.41894530e-01,   5.55555556e-01],
#        [  1.10000000e+02,   6.68640135e-01,   6.66666667e-01],
#        [  1.10000000e+02,   6.41894530e-01,   7.77777778e-01],
#        [  0.00000000e+00,   6.41894530e-01,   8.88888889e-01],
#        [  1.10000000e+02,   5.88403319e-01,   1.00000000e+00],
#        [  0.00000000e+00,   6.68640135e-01,   1.11111111e+00],
#        [  0.00000000e+00,   6.95385740e-01,   1.22222222e+00],
#        [  1.10000000e+02,   5.34912108e-01,   1.33333333e+00],
#        [  1.10000000e+02,   6.41894530e-01,   1.44444444e+00],
#        [  0.00000000e+00,   6.95385740e-01,   1.55555556e+00],
#        [  0.00000000e+00,   6.95385740e-01,   1.66666667e+00],
#        [  1.10000000e+02,   5.34912108e-01,   1.77777778e+00],
#        [  0.00000000e+00,   6.41894530e-01,   1.88888889e+00],
#        [  0.00000000e+00,   6.41894530e-01,   2.00000000e+00],
#        [  0.00000000e+00,   6.68640135e-01,   2.11111111e+00],
#        [  1.10000000e+02,   6.68640135e-01,   2.22222222e+00],
#        [  0.00000000e+00,   7.22131346e-01,   2.33333333e+00],
#        [  0.00000000e+00,   5.88403319e-01,   2.44444444e+00],
#        [  0.00000000e+00,   6.41894530e-01,   2.55555556e+00],
#        [  0.00000000e+00,   6.95385740e-01,   2.66666667e+00],
#        [  0.00000000e+00,   7.22131346e-01,   2.77777778e+00],
#        [  1.10000000e+02,   7.22131346e-01,   2.88888889e+00],
#        [  0.00000000e+00,   7.22131346e-01,   3.00000000e+00],
#        [  0.00000000e+00,   8.02368162e-01,   3.11111111e+00],
#        [  1.10000000e+02,   8.29113767e-01,   3.22222222e+00],
#        [  0.00000000e+00,   8.29113767e-01,   3.33333333e+00],
#        [  1.10000000e+02,   8.02368162e-01,   3.44444444e+00],
#        [  0.00000000e+00,   8.29113767e-01,   3.55555556e+00],
#        [  0.00000000e+00,   8.55859373e-01,   3.66666667e+00],
#        [  0.00000000e+00,   8.29113767e-01,   3.77777778e+00],
#        [  1.10000000e+02,   8.29113767e-01,   3.88888889e+00],
#        [  0.00000000e+00,   8.55859373e-01,   4.00000000e+00],
#        [  1.10000000e+02,   9.09350584e-01,   4.11111111e+00],
#        [  0.00000000e+00,   8.29113767e-01,   4.22222222e+00],
#        [  1.10000000e+02,   8.02368162e-01,   4.33333333e+00],
#        [  1.20000000e+02,   8.29113767e-01,   4.44444444e+00],
#        [  0.00000000e+00,   7.75622557e-01,   4.55555556e+00],
#        [  1.10000000e+02,   7.75622557e-01,   4.66666667e+00],
#        [  1.10000000e+02,   8.02368162e-01,   4.77777778e+00],
#        [  0.00000000e+00,   7.22131346e-01,   4.88888889e+00],
#        [  0.00000000e+00,   5.88403319e-01,   5.00000000e+00],
#        [  0.00000000e+00,   5.88403319e-01,   5.11111111e+00],
#        [  0.00000000e+00,   5.61657713e-01,   5.22222222e+00],
#        [  0.00000000e+00,   6.41894530e-01,   5.33333333e+00],
#        [  0.00000000e+00,   5.34912108e-01,   5.44444444e+00],
#        [  0.00000000e+00,   6.41894530e-01,   5.55555556e+00],
#        [  0.00000000e+00,   6.41894530e-01,   5.66666667e+00],
#        [  1.10000000e+02,   6.41894530e-01,   5.77777778e+00],
#        [  0.00000000e+00,   6.41894530e-01,   5.88888889e+00],
#        [  0.00000000e+00,   6.41894530e-01,   6.00000000e+00],
#        [  0.00000000e+00,   6.41894530e-01,   6.11111111e+00],
#        [  0.00000000e+00,   5.88403319e-01,   6.22222222e+00],
#        [  0.00000000e+00,   6.41894530e-01,   6.33333333e+00],
#        [  1.00000000e+02,   5.34912108e-01,   6.44444444e+00],
#        [  1.00000000e+02,   4.54675292e-01,   6.55555556e+00],
#        [  0.00000000e+00,   4.81420897e-01,   6.66666667e+00],
#        [  0.00000000e+00,   5.34912108e-01,   6.77777778e+00],
#        [  1.10000000e+02,   5.88403319e-01,   6.88888889e+00],
#        [  1.00000000e+02,   6.68640135e-01,   7.00000000e+00],
#        [  1.00000000e+02,   6.41894530e-01,   7.11111111e+00],
#        [  0.00000000e+00,   7.75622557e-01,   7.22222222e+00],
#        [  0.00000000e+00,   6.68640135e-01,   7.33333333e+00],
#        [  0.00000000e+00,   6.95385740e-01,   7.44444444e+00],
#        [  0.00000000e+00,   6.68640135e-01,   7.55555556e+00],
#        [  1.00000000e+02,   7.75622557e-01,   7.66666667e+00],
#        [  0.00000000e+00,   7.75622557e-01,   7.77777778e+00],
#        [  1.00000000e+02,   7.75622557e-01,   7.88888889e+00],
#        [  1.00000000e+02,   8.02368162e-01,   8.00000000e+00],
#        [  0.00000000e+00,   8.02368162e-01,   8.11111111e+00],
#        [  1.00000000e+02,   7.75622557e-01,   8.22222222e+00],
#        [  0.00000000e+00,   7.75622557e-01,   8.33333333e+00],
#        [  0.00000000e+00,   7.75622557e-01,   8.44444444e+00],
#        [  0.00000000e+00,   8.29113767e-01,   8.55555556e+00],
#        [  0.00000000e+00,   8.02368162e-01,   8.66666667e+00],
#        [  0.00000000e+00,   8.55859373e-01,   8.77777778e+00],
#        [  0.00000000e+00,   7.22131346e-01,   8.88888889e+00],
#        [  0.00000000e+00,   7.22131346e-01,   9.00000000e+00],
#        [  1.00000000e+02,   6.95385740e-01,   9.11111111e+00],
#        [  0.00000000e+00,   8.02368162e-01,   9.22222222e+00],
#        [  0.00000000e+00,   8.02368162e-01,   9.33333333e+00],
#        [  1.00000000e+02,   6.68640135e-01,   9.44444444e+00],
#        [  1.00000000e+02,   7.75622557e-01,   9.55555556e+00],
#        [  0.00000000e+00,   7.22131346e-01,   9.66666667e+00],
#        [  0.00000000e+00,   6.68640135e-01,   9.77777778e+00],
#        [  1.00000000e+02,   6.95385740e-01,   9.88888889e+00],
#        [  0.00000000e+00,   7.22131346e-01,   1.00000000e+01]])

# %%
np.zeros(
# Out:
# [array([ 0.]),
#  array([ 1.11111111]),
#  array([ 2.22222222]),
#  array([ 3.33333333]),
#  array([ 4.44444444]),
#  array([ 5.55555556]),
#  array([ 6.66666667]),
#  array([ 7.77777778]),
#  array([ 8.88888889]),
#  array([ 10.])]

# %%
a = np.array([[1],[2],[3]])
b = np.split(np.linspace(0.0, 10.0, num=3),3)
np.hstack((a,b))
# Out:
# array([[  1.,   0.],
#        [  2.,   5.],
#        [  3.,  10.]])

# %%
a = np.array([1,2,3])
b = np.linspace(0.0, 10.0, num=3)
np.hstack((a,b))
# Out:
# array([  1.,   2.,   3.,   0.,   5.,  10.])

# %%
scene.visuals.Text(
# Out:
# array([  0.        ,   1.11111111,   2.22222222,   3.33333333,
#          4.44444444,   5.55555556,   6.66666667,   7.77777778,
#          8.88888889,  10.        ])
